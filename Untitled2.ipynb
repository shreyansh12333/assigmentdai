# %%
import pandas as pd

# %%
data = pd.read_csv('workout_fitness_tracker_data.csv')
# Out:
#       User ID  Age  Gender  Height (cm)  Weight (kg) Workout Type  \
# 0           1   39    Male          175           99      Cycling
# 1           2   36   Other          157          112       Cardio
# 2           3   25  Female          180           66         HIIT
# 3           4   56    Male          154           89      Cycling
# 4           5   53   Other          194           59     Strength
# ...       ...  ...     ...          ...          ...          ...
# 9995     9996   20   Other          173           59         Yoga
# 9996     9997   29  Female          171           71         HIIT
# 9997     9998   47    Male          183           75      Running
# 9998     9999   52    Male          170           97         HIIT
# 9999    10000   47  Female          186           88         HIIT
#
#       Workout Duration (mins)  Calories Burned  Heart Rate (bpm)  Steps Taken  \
# 0                          79              384               112         8850
# ...

# %%
data.head()
# Out:
#    User ID  Age  Gender  Height (cm)  Weight (kg) Workout Type  \
# 0        1   39    Male          175           99      Cycling
# 1        2   36   Other          157          112       Cardio
# 2        3   25  Female          180           66         HIIT
# 3        4   56    Male          154           89      Cycling
# 4        5   53   Other          194           59     Strength
#
#    Workout Duration (mins)  Calories Burned  Heart Rate (bpm)  Steps Taken  \
# 0                       79              384               112         8850
# 1                       73              612               168         2821
# 2                       27              540               133        18898
# 3                       39              672               118        14102
# 4                       56              410               170        16518
#
#    Distance (km) Workout Intensity  Sleep Hours  Water Intake (liters)  \
# ...

# %%
data.columns
# Out:
# Index(['User ID', 'Age', 'Gender', 'Height (cm)', 'Weight (kg)',
#        'Workout Type', 'Workout Duration (mins)', 'Calories Burned',
#        'Heart Rate (bpm)', 'Steps Taken', 'Distance (km)', 'Workout Intensity',
#        'Sleep Hours', 'Water Intake (liters)', 'Daily Calories Intake',
#        'Resting Heart Rate (bpm)', 'VO2 Max', 'Body Fat (%)',
#        'Mood Before Workout', 'Mood After Workout'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   User ID                   10000 non-null  int64
#  1   Age                       10000 non-null  int64
#  2   Gender                    10000 non-null  object
#  3   Height (cm)               10000 non-null  int64
#  4   Weight (kg)               10000 non-null  int64
#  5   Workout Type              10000 non-null  object
#  6   Workout Duration (mins)   10000 non-null  int64
#  7   Calories Burned           10000 non-null  int64
#  8   Heart Rate (bpm)          10000 non-null  int64
#  9   Steps Taken               10000 non-null  int64
#  10  Distance (km)             10000 non-null  float64
#  11  Workout Intensity         10000 non-null  object
#  12  Sleep Hours               10000 non-null  float64
# ...

# %%
data.isnull().sum()
# Out:
# User ID                     0
# Age                         0
# Gender                      0
# Height (cm)                 0
# Weight (kg)                 0
# Workout Type                0
# Workout Duration (mins)     0
# Calories Burned             0
# Heart Rate (bpm)            0
# Steps Taken                 0
# Distance (km)               0
# Workout Intensity           0
# Sleep Hours                 0
# Water Intake (liters)       0
# Daily Calories Intake       0
# Resting Heart Rate (bpm)    0
# VO2 Max                     0
# Body Fat (%)                0
# Mood Before Workout         0
# Mood After Workout          0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.drop(columns = ['User ID']).describe()
# Out:
#                 Age   Height (cm)   Weight (kg)  Workout Duration (mins)  \
# count  10000.000000  10000.000000  10000.000000             10000.000000
# mean      38.390100    174.275100     84.903000                64.464800
# std       12.171637     14.440986     20.189937                31.814946
# min       18.000000    150.000000     50.000000                10.000000
# 25%       28.000000    162.000000     67.000000                37.000000
# 50%       38.000000    174.000000     85.000000                64.000000
# 75%       49.000000    187.000000    102.000000                92.000000
# max       59.000000    199.000000    119.000000               119.000000
#
#        Calories Burned  Heart Rate (bpm)   Steps Taken  Distance (km)  \
# count     10000.000000      10000.000000  10000.000000   10000.000000
# mean        552.100800        129.526700  10455.496600       7.820745
# std         260.629908         28.874152   5486.423716       4.159148
# ...

# %%
#UNIVARIATE ANALYSIS
num_col = ['Age','Height (cm)', 'Weight (kg)','Workout Duration (mins)', 'Calories Burned','Heart Rate (bpm)', 'Steps Taken', 'Distance (km)','Sleep Hours', 'Daily Calories Intake','Resting Heart Rate (bpm)']
len(num_col)
# Out:
# 11

# %%
import warnings 
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
warnings.filterwarnings('ignore') 
plt.figure(figsize = (15,12))
for i, cols in enumerate(num_col):
    plt.subplot(4,3,i+1)
    sns.histplot(data = data,x = cols,kde = True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize = (12,10))
#performing outlier detection
for i, cols in enumerate(num_col):
    plt.subplot(4,3,i+1)
    sns.boxplot(data = data,x = cols)
plt.tight_layout()
plt.show()

# %%
#skewness
data[num_col].skew()
# Out:
# Age                         0.006229
# Height (cm)                 0.017389
# Weight (kg)                -0.024774
# Workout Duration (mins)    -0.008162
# Calories Burned            -0.015803
# Heart Rate (bpm)           -0.003818
# Steps Taken                 0.006778
# Distance (km)              -0.012480
# Sleep Hours                 0.005073
# Daily Calories Intake      -0.004375
# Resting Heart Rate (bpm)    0.008110
# dtype: float64

# %%
#UNIVARIATE ANALYSIS ON CATEGORICAL COLUMNS
cat_col = ['Gender','Workout Type','Workout Intensity','Mood Before Workout','Mood After Workout']
plt.figure(figsize = (12,6))

for i,cols in enumerate(cat_col):
    plt.subplot(2,3,1+i)
    sns.countplot(data=data,x=cols)
plt.tight_layout()
plt.show()

# %%
#WORKOUT TYPE VS HEART RATE
data['Heart Rate (bpm)'].mean()
# Out:
# 129.5267

# %%
plt.figure(figsize=(10,4))
sns.boxplot(data=data,x= 'Workout Type',y='Heart Rate (bpm)')
# Out:
# <Axes: xlabel='Workout Type', ylabel='Heart Rate (bpm)'>

# %%
sns.violinplot(data=data,x= 'Workout Intensity',y='Height (cm)',hue='Gender')
# Out:
# <Axes: xlabel='Workout Intensity', ylabel='Height (cm)'>

# %%
#AGE VS WORKOUT DURATION
sns.histplot(data=data,x= 'Age',y='Workout Duration (mins)',cmap='viridis')
sns.color_palette("viridis", as_cmap=True)
"""
Tend to have higher workout durations (~45-60 mins on average).
Likely due to greater energy levels, fitness enthusiasm, or structured workout routines.
Shows a wider range of workout durations, but the median is slightly lower (~30-45 mins).
Likely due to time constraints (work, family) or a shift towards moderate-intensity workouts.
Generally engage in shorter workouts (~20-40 mins).
Likely due to a preference for lower-intensity exercises (e.g., walking, light strength training).


"""

# %%
sns.boxplot(data=data,x = 'Workout Intensity',y='Sleep Hours')
"""
Individuals with moderate workout intensity tend to have consistent sleep durations, around 6-8 hours on average.
This suggests that moderate exercise helps maintain a stable sleep pattern.
High-intensity workout participants show greater variability in sleep hours.
Some individuals sleep longer (~9 hours), possibly for recovery, while others sleep less (~5 hours), possibly due to overtraining effects.
Those engaging in low-intensity workouts tend to have lower median sleep hours (~6 hours).
This might indicate that lower activity levels are linked to less restful or shorter sleep durations
"""
# Out:
# <Axes: xlabel='Workout Intensity', ylabel='Sleep Hours'>

# %%
data['heart_rate_difference'] = data['Heart Rate (bpm)'] - data['Resting Heart Rate (bpm)']

# %%
#HEART RATE DIFFERENCES DURING WORKOUTS
plt.figure(figsize = (8,6))
sns.barplot(data=data,x = 'Workout Type', y ='heart_rate_difference',hue='Gender')
"""
HIIT and Cardio workouts show the highest heart rate increase, indicating their intensity.
Strength training and cycling have moderate heart rate increases, likely due to resistance-based efforts and pacing
Males and females show similar trends across workout types, but males tend to have slightly higher heart rate increases in HIIT and Strength workouts.
Females show more variation in heart rate responses, possibly due to different fitness levels or training styles.
Cycling and Strength training show lower heart rate increases compared to HIIT and Cardio, suggesting lower cardiovascular demand in these exercises.
This aligns with expectations, as endurance-based workouts (Cycling) often allow the heart rate to stabilize.
"""
# Out:
# <Axes: xlabel='Workout Type', ylabel='heart_rate_difference'>

# %%
sns.kdeplot(data=data,x = 'Workout Duration (mins)', y = 'Heart Rate (bpm)',fill=True)
"""
There are high-density regions where heart rates cluster around 120-160 bpm for workout durations between 20 to 60 minutes.
This suggests that most users maintain a moderate-to-high heart rate within this duration range.
As workout durations exceed 60 minutes, heart rates tend to stabilize around 110-140 bpm.
This could indicate that users pace themselves during longer workouts to avoid excessive fatigue.
For workouts lasting less than 30 minutes, we observe a higher heart rate concentration above 140 bpm.
This suggests that shorter workouts often involve high-intensity exercises like HIIT, leading to elevated heart rates
"""
# Out:
# <Axes: xlabel='Workout Duration (mins)', ylabel='Heart Rate (bpm)'>

# %%
a = data[['Age','Height (cm)', 'Weight (kg)','Workout Duration (mins)', 'Calories Burned','Heart Rate (bpm)', 'Steps Taken', 'Distance (km)','Sleep Hours', 'Daily Calories Intake','Resting Heart Rate (bpm)']]

# %%
a = plt.imshow(a.corr())

# make bar 
bar = plt.colorbar(a)

# %%
plt.figure(figsize=(10, 5))
sns.scatterplot(data=df, x="Sleep Hours", y="Calories Burned", hue="Workout Intensity", alpha=0.6)
plt.title("Impact of Sleep on Calories Burned")
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.scatterplot(data=df, x="Steps Taken", y="Distance (km)", alpha=0.5)
plt.title("Steps Taken vs Distance Covered")
plt.show()

# %% [markdown]
# KEY INSIGHTS

# %% [raw]
# 1). Calories Burned vs. Workout Type & Intensity
#
# High-intensity workouts burn significantly more calories across all workout types.
# HIIT and Cardio workouts tend to burn more calories compared to Strength Training and Cycling.
# Strength workouts show a lower variance in calorie burn, likely due to shorter workout durations.
# 2). Sleep Hours & Workout Performance (Calories Burned)
#
# Users with longer sleep durations (7+ hours) generally burn more calories.
# Users with less sleep (<6 hours) show more variation, with some burning fewer calories, possibly due to fatigue.
# This suggests that adequate sleep enhances workout efficiency.
# 3). Steps Taken vs. Distance Covered
#
# A clear positive correlation: More steps taken results in a greater distance covered.
# Some variation may be due to different stride lengths or workout types (e.g., cycling vs. running).
